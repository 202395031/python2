# %% [markdown]
# # 1. 헌법 워드클라우드

# %%
# 한국어 자연어 처리 패키지 설치
# !pip install konlpy

# %%
# 라이브러리 불러오기
from wordcloud import WordCloud # 워드클라우드 생성을 위한 라이브러리
import matplotlib.pyplot as plt # 그래프 및 시각화를 위한 라이브러리
from collections import Counter # 리스트 요소의 개수를 셀 때 사용하는 라이브러리
from konlpy.tag import Okt      # 한국어 텍스트를 형태소 분석하기 위한 라이브러리
import numpy as np              # 배열 및 행렬 연산을 위한 라이브러리

okt = Okt() # 형태소 분석기 초기화

# %%
# 텍스트 분석하기

#파일 오픈
with open("대한민국헌법.txt", 'r', encoding='utf-8') as f :
    text = f.read()

# 형태소 분석을 통해 명사를 추출
nouns = okt.nouns(text)

# 한글자 이상의 명사만 추출
words = [n for n in nouns if len(n) > 1]

# 단어의 빈도수 계산
c = Counter(words)

# 코렙에서 제공하는 한글 폰트 사용을 위해 설정합니다.
plt.rc('font', family="NaumGothic")
font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

# # 워드 클라우드 생성을 위한 설정
# font_path = '/content/H2GTRE.TTF'    # 업로드 한 폰트.
# wc = WordCloud(width=400, height=400, font_path=font_path, max_font_size=250)

# 단어의 빈도수에 따라 워드클라우드 생성
gen = wc.generate_from_frequencies(c)

# 워드클라우드 시각화 및 이미지 파일로 저장
plt.figure()
plt.imshow(gen)
wc.to_file('헌법클라우드.png')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 애국가 분석하기
#파일 오픈
with open("애국가.txt", 'r', encoding='utf-8') as f :
    text = f.read()

# 애국가 형태소 분석
nouns = okt.nouns(text)

# 한글자 이상의 명사만 추출
words = [n for n in nouns if len(n) > 1]

# 단어의 빈도수 계산
c = Counter(words)

# # 워드 클라우드 생성을 위한 설정
font_path = '/content/H2GTRE.TTF'    # 업로드 한 폰트.
wc = WordCloud(width=400, height=400, font_path=font_path, max_font_size=250)

# 단어의 빈도수에 따라 워드클라우드 생성
gen = wc.generate_from_frequencies(c)

# 워드클라우드 시각화 및 이미지 파일로 저장
plt.figure()
plt.imshow(gen)
wc.to_file('애국가.png')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NaumGothic' not found.
